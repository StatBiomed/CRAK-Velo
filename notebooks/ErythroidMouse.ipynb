# %%
import scvelo as scv

# %%
adata = scv.read('../trails/checkpoints/VelocityDemo/0602_202130/model_last.h5ad')

# %%
scv.pl.velocity_embedding_stream(adata, color='celltype', dpi=100, title='')

# %%
scv.tl.latent_time(adata, min_likelihood=None)
scv.pl.scatter(adata, color='latent_time', color_map='gnuplot', size=20)
# Out:
# computing latent time using root_cells as prior
#     finished (0:00:03) --> added
#     'latent_time', shared time (adata.obs)
